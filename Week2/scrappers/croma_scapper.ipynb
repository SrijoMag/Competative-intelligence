# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd 
from datetime import datetime

# %%
url="https://www.croma.com/boat-nirvana-ion-anc-pro-tws-earbuds-with-active-noise-cancellation-ipx4-water-resistant-dual-eq-modes-crystal-black-/p/319481"
headers={"User-Agent":"Mozilla/5.0"}
respo=requests.get(url,headers=headers)
print("Status: ",respo.status_code)
# Out:
# Status:  403

# %%
print(respo.text[:20000])
# Out:
# <HTML><HEAD>
# <TITLE>Access Denied</TITLE>
# </HEAD><BODY>
# <H1>Access Denied</H1>
#
# You don't have permission to access "http&#58;&#47;&#47;www&#46;croma&#46;com&#47;boat&#45;nirvana&#45;ion&#45;anc&#45;pro&#45;tws&#45;earbuds&#45;with&#45;active&#45;noise&#45;cancellation&#45;ipx4&#45;water&#45;resistant&#45;dual&#45;eq&#45;modes&#45;crystal&#45;black&#45;&#47;p&#47;319481" on this server.<P>
# Reference&#32;&#35;18&#46;d7f43717&#46;1780718669&#46;31e764d1
# <P>https&#58;&#47;&#47;errors&#46;edgesuite&#46;net&#47;18&#46;d7f43717&#46;1780718669&#46;31e764d1</P>
# </BODY>
# </HTML>

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\KIIT0001\anaconda3\python.exe

# %%
import sys

# !{sys.executable} -m pip install playwright
# Out:
# ...
#   Using cached playwright-1.60.0-py3-none-win_amd64.whl.metadata (3.5 kB)
# ...
#   Using cached pyee-13.0.1-py3-none-any.whl.metadata (3.0 kB)
# ...
# Using cached playwright-1.60.0-py3-none-win_amd64.whl (37.9 MB)
# Using cached pyee-13.0.1-py3-none-any.whl (15 kB)
# ...
#
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
# ...

# %%
import sys

# !{sys.executable} -m playwright install
# Out:
# ...
# Error: read ECONNRESET
#     at TLSWrap.onStreamRead (node:internal/stream_base_commons:216:20) {
#   errno: -4077,
#   code: 'ECONNRESET',
#   syscall: 'read'
# }
# Error: getaddrinfo ENOTFOUND cdn.playwright.dev
#     at GetAddrInfoReqWrap.onlookupall [as oncomplete] (node:internal/dns/promises:101:17) {
#   errno: -3008,
#   code: 'ENOTFOUND',
#   syscall: 'getaddrinfo',
#   hostname: 'cdn.playwright.dev'
# }
# Error: getaddrinfo ENOTFOUND cdn.playwright.dev
#     at GetAddrInfoReqWrap.onlookupall [as oncomplete] (node:internal/dns/promises:101:17) {
#   errno: -3008,
#   code: 'ENOTFOUND',
#   syscall: 'getaddrinfo',
#   hostname: 'cdn.playwright.dev'
# }
# Error: getaddrinfo ENOTFOUND cdn.playwright.dev
#     at GetAddrInfoReqWrap.onlookupall [as oncomplete] (node:internal/dns/promises:101:17) {
#   errno: -3008,
#   code: 'ENOTFOUND',
#   syscall: 'getaddrinfo',
#   hostname: 'cdn.playwright.dev'
# }
# Error: getaddrinfo ENOTFOUND cdn.playwright.dev
# ...

# %%
from playwright.sync_api import sync_playwright
print("Playwright installed successfully")
# Out:
# Playwright installed successfully

# %%
async def test_browser():
    async with async_playwright() as p:
        brows=await p.chromium.launch(headless=False)
        page=await brows.new_page()
        await page.goto("https://www.google.com")
        print(page.title())
        await brows.close()
